# %% [markdown]
# ### Possibly interesting features based on https://news.ycombinator.com/item?id=36590226
# - Time of day [Done]
# - Analysis on title: TF-IDF? Remove stopwords? Any other importance measures, and onehot encode the impt words?

# %%
import os

import pandas as pd

from pyspark.sql import SQLContext, Window
from pyspark.sql.functions import col,sum,desc,when,udf, percent_rank

from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.classification import LogisticRegression, LinearSVC, RandomForestClassifier
from pyspark.ml.feature import VectorAssembler, StandardScaler, StringIndexer, OneHotEncoder, Tokenizer, StopWordsRemover, CountVectorizer, IDF, PCA, HashingTF


from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
sc
# Out:
# <SparkContext master=local[2] appName=PySparkShell>

# %%
# Change file path
os.chdir("/Users/hydraze/Library/CloudStorage/GoogleDrive-tohziyu2@gmail.com/My Drive/Studies/KU Leuven/Courses/Classes/Y1S2/Advanced Analytics in Business/Project/3/AdvancedAnalytics_Streaming-Text-Analytics")

# %%
# Load all folder names, then read into one text file
file_path = "/Users/hydraze/Library/CloudStorage/GoogleDrive-tohziyu2@gmail.com/My Drive/Studies/KU Leuven/Courses/Classes/Y1S2/Advanced Analytics in Business/Project/3/AdvancedAnalytics_Streaming-Text-Analytics/"
folders_names = [file_path + 'data/' + folder for folder in os.listdir(file_path + 'data/') if "saved_stories" in folder]
compiled_stories = sc.textFile(','.join(folders_names[0:250]))

# %%
df = spark.read.json(compiled_stories)

# %%
# Try to speed things up by coalescing the partitions
df = df.coalesce(10)

# %%
# # Max and min posted-at date
# min_date = df.agg({"posted_at": "min"}).collect()[0][0]
# max_date = df.agg({"posted_at": "max"}).collect()[0][0]
# print(f"min posted at date: {min_date}")
# print(f"min posted at date: {max_date}")

# %%
# Convert frontpage to numeric
df = df.withColumn('frontpage', when(df.frontpage==True, 1).otherwise(0))

# %%
# Compile cleaning steps which cannot be fit into a pipeline. These steps will not cause data leakage
# Will have to be implemented on the script for doing streaming predictions

# Extracting type of post: Show HN
df = df.withColumn('isShowHN', when(df.title.contains("Show HN"), 1).otherwise(0))

# Extracting time of day
extract_time_of_day_udf = udf(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S').strftime('%H'))


df = df.withColumn('time_of_day', extract_time_of_day_udf(df.posted_at))

# Extracting day of week
weekDay =  udf(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S').strftime('%w'))

df = df.withColumn('day_of_week', weekDay(df.posted_at))

# Fill null values
df = df.na.fill({"title": "", "source_title": "", "source_text": ""})

# %% [markdown]
# ### Modelling time

# %%
# Train test split based on time: Have to prevent data leakage. Sort dataframe by posted_at, and give a percentile rank allowing us to 
# split the dataset in to two parts based on time
df = df.withColumn("rank", percent_rank().over(Window.partitionBy().orderBy("posted_at"))).collect() # Computationally heavy step. to collect here first
df = spark.createDataFrame(df)

train = df.where("rank <= .8").drop("rank")
test = df.where("rank > .8").drop("rank")
# Out:
# 24/05/16 23:15:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 23:15:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 23:15:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 23:15:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 23:15:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %%
# Other cleaning stages which can be fit into a pipeline. Will automatically apply all steps to test set
NUM_COL = ['votes', 'comments']

# Dealing with numerical variables
numerical_vector_assembler = VectorAssembler(inputCols=NUM_COL, outputCol='num_col_vector')
std_scaler = StandardScaler(inputCol='num_col_vector',
                            outputCol='scaled_num_col_vector',
                            withStd=True, withMean=True)

# Dealing with categorical variables
isShowHN_indexer = StringIndexer(inputCol='isShowHN',
                            outputCol='isShowHN_index',handleInvalid = "keep")
isShowHN_ohe = OneHotEncoder(inputCol='isShowHN_index',
                                outputCol='isShowHN_OHE',handleInvalid = "keep")

time_of_day_indexer = StringIndexer(inputCol='time_of_day',
                            outputCol='time_of_day_index',handleInvalid = "keep")
time_of_day_ohe = OneHotEncoder(inputCol='time_of_day_index',
                                outputCol='time_of_day_OHE',handleInvalid = "keep")

day_of_week_indexer = StringIndexer(inputCol='day_of_week',
                            outputCol='day_of_week_index',handleInvalid = "keep")
day_of_week_ohe = OneHotEncoder(inputCol='day_of_week_index',
                                outputCol='day_of_week_OHE',handleInvalid = "keep")

# Text processing steps
# 1. Tokenization
tokenizer_title = Tokenizer(inputCol="title", outputCol="title_tokens")
tokenizer_source = Tokenizer(inputCol="source_title", outputCol="source_title_tokens")

# 2. Stop Word Removal
remover_title = StopWordsRemover(inputCol="title_tokens", outputCol="title_filtered")
remover_source = StopWordsRemover(inputCol="source_title_tokens", outputCol="source_title_filtered")

# 3. Hashing
hashingTF_title = HashingTF(inputCol="title_filtered", outputCol="title_rawFeatures", numFeatures=20)
hashingTF_source = HashingTF(inputCol="source_title_filtered", outputCol="source_rawFeatures", numFeatures=20)

# 4. TF-IDF
idf_title = IDF(inputCol="title_rawFeatures", outputCol="title_features")
idf_source = IDF(inputCol="source_rawFeatures", outputCol="source_features")

# 5. PCA - Cut hash feastures by half
pca_title = PCA(k=10, inputCol="title_features", outputCol="title_pcaFeatures")
pca_source = PCA(k=10, inputCol="source_features", outputCol="source_pcaFeatures")

# To put all numerical vectors and onehotencoded categorical variables into the same final_feature_vector vector
overall_assembler = VectorAssembler(inputCols=['scaled_num_col_vector',
                                               'isShowHN_OHE',
                                               'time_of_day_OHE',
                                               'day_of_week_OHE',
                                              'title_pcaFeatures',
                                              'source_pcaFeatures'],
                                    outputCol='final_feature_vector')

# %%
# Initiate model(s) and params
lr = LogisticRegression(maxIter=100, family="binomial",
                        featuresCol='final_feature_vector', labelCol='frontpage',
                        weightCol="frontpage")

param_grid_lr = (ParamGridBuilder()
                .addGrid(lr.regParam, [0.2, 0.6, 0.8, 1]) 
                .addGrid(lr.elasticNetParam, [0.0, 0.2, 0.8, 1.0]) 
                .build())

rfc = RandomForestClassifier(maxDepth=30, seed=42, weightCol="frontpage", 
                             labelCol='frontpage', featuresCol='final_feature_vector')

param_grid_rfc = (ParamGridBuilder()
                 .addGrid(rfc.numTrees, [10, 20, 160, 640]) 
                 .addGrid(rfc.impurity, ['gini', 'entropy']) 
                 .build())

svc = LinearSVC(weightCol="frontpage", labelCol='frontpage', featuresCol='final_feature_vector')

param_grid_svc = (ParamGridBuilder()
                .addGrid(svc.regParam, [0.001, 0.1, 1, 10, 1000]) 
                .build())

# %%
# Compile final pipelines
cleaning_stages = [numerical_vector_assembler,
                   std_scaler, 
                   isShowHN_indexer, 
                   isShowHN_ohe,
                   time_of_day_indexer, 
                   time_of_day_ohe,
                   day_of_week_indexer, 
                   day_of_week_ohe,
                   tokenizer_title, 
                   tokenizer_source,
                   remover_title,
                   remover_source,
                   hashingTF_title,
                   hashingTF_source,
                   idf_title,
                   idf_source,
                   pca_title,
                   pca_source,
                   overall_assembler]

pipeline_lr = Pipeline(stages=cleaning_stages + [lr])
pipeline_rfc = Pipeline(stages=cleaning_stages + [rfc])
pipeline_svc = Pipeline(stages=cleaning_stages + [svc])

# %%
# Defining evaluator and crossvalidation object
evaluator = BinaryClassificationEvaluator().setLabelCol("frontpage")

kfolds = 2
seed = 42
n_cores = 4

# Join everything together using a CrossValidator object for each model
crossval_lr = CrossValidator(
    estimator=pipeline_lr, 
    estimatorParamMaps=param_grid_lr, 
    evaluator=evaluator, 
    numFolds=kfolds,
    parallelism=n_cores, 
    seed=seed
)

crossval_rfc = CrossValidator(
    estimator=pipeline_rfc, 
    estimatorParamMaps=param_grid_rfc, 
    evaluator=evaluator, 
    numFolds=kfolds,
    parallelism=n_cores, 
    seed=seed
)

crossval_svc = CrossValidator(
    estimator=pipeline_svc, 
    estimatorParamMaps=param_grid_svc, 
    evaluator=evaluator, 
    numFolds=kfolds,
    parallelism=n_cores, 
    seed=seed
)

# %%
# Training and evaluating LR
cvModel_lr = crossval_lr.fit(train)

best_model_lr = cvModel_lr.bestModel
best_score_lr = cvModel_lr.avgMetrics[0]

print("Best LR model: ", best_model_lr)
print("Best LR score: ", best_score_lr)

print("\n")

best_lr_params = best_model_lr.stages[-1].extractParamMap()
for parameter, value in best_lr_params.items():
    print(f"{str(parameter):50s}, {value}")

print("\n")

# Test scores
test_pred_lr = best_model_lr.transform(test)
print("Test scores for LR", evaluator.evaluate(test_pred_lr))
# Out:
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4088 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4089 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4090 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4091 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4092 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4093 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4094 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4095 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4104 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4105 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4106 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4107 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4116 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4118 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4119 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4117 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4128 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4129 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4130 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:24 WARN TaskSetManager: Stage 4131 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4140 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4141 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4142 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4143 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4144 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4145 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4146 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4147 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4148 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4149 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4150 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4151 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4152 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4153 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4154 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4155 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4156 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4157 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4158 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4159 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4160 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4161 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4162 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4163 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4164 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4165 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4166 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4167 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4168 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4169 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4170 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4171 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4172 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4173 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4174 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4175 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4176 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4177 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4178 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4179 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4180 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4181 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4182 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4183 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4184 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4185 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4186 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4187 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4188 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4189 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4190 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4191 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:25 WARN TaskSetManager: Stage 4192 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4193 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN Instrumentation: [74e1689a] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4194 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN Instrumentation: [60f7248c] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4195 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN Instrumentation: [2d6f218f] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:26 WARN Instrumentation: [f0935262] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4196 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4197 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4198 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4199 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4200 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4202 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4204 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:26 WARN TaskSetManager: Stage 4206 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4244 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4245 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4247 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4246 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4256 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4257 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4258 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4259 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4268 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4269 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4270 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4271 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4280 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4281 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4282 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4283 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4292 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4293 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4294 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4295 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4296 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4297 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4298 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4299 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4300 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4301 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4302 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4303 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4304 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4305 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4306 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4307 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4308 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4309 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4310 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4311 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4312 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4313 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4314 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4315 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4316 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4317 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:27 WARN TaskSetManager: Stage 4318 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4319 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4320 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4321 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4322 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4323 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4324 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4325 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4326 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4327 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4328 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4329 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4330 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4331 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4332 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4333 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4334 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4335 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4336 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4337 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4338 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4339 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4340 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4341 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4342 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4343 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4344 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4345 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN Instrumentation: [110aa865] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4346 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN Instrumentation: [bf2d9106] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4347 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN Instrumentation: [56f72819] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:28 WARN Instrumentation: [d9116521] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4348 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4350 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:28 WARN TaskSetManager: Stage 4352 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4354 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4392 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4394 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4393 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4395 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4404 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4405 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4406 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4407 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4416 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4417 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4418 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4419 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4428 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4429 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4430 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4431 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4440 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4441 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4442 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4443 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4444 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4445 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4446 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:29 WARN TaskSetManager: Stage 4447 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4448 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4449 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4450 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4451 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4452 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4453 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4454 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4455 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4456 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4457 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4458 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4459 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4460 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4461 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4462 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4463 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4464 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4465 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4466 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4467 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4468 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4469 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4470 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4471 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4472 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4473 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4474 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4475 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4476 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4477 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4478 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4479 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4480 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4481 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4482 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4483 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4484 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4485 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4486 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4487 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4488 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4489 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4490 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4491 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4492 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4493 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN Instrumentation: [4e9f5d7c] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4494 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN Instrumentation: [a7a63577] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:30 WARN TaskSetManager: Stage 4495 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:30 WARN Instrumentation: [71e25b3a] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:30 WARN Instrumentation: [d3c9ae05] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4496 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4498 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4500 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4502 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4540 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4541 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4542 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4543 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4552 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4553 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4554 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4555 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4564 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4565 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4566 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4567 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4576 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4577 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4578 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4579 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4588 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4589 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4590 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4591 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4592 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4593 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:31 WARN TaskSetManager: Stage 4594 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4595 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4596 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4597 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4598 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4599 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4600 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4601 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4602 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4603 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4604 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4605 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4606 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4607 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4608 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4609 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4610 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4611 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4612 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4613 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4614 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4615 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4616 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4617 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4618 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4619 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4620 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4621 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4622 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4623 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4624 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4625 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4626 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4627 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4628 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4629 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4630 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4631 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4632 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4633 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4634 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4635 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4636 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4637 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4638 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4639 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4640 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4641 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN Instrumentation: [22fca379] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4642 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN Instrumentation: [c683bfa4] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:32 WARN TaskSetManager: Stage 4643 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:32 WARN Instrumentation: [8c54857f] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:32 WARN Instrumentation: [ff22a0b5] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4644 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4646 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4648 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4650 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4688 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4689 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:33 WARN TaskSetManager: Stage 4690 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# ...
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5098 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5100 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5102 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5140 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5141 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5142 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5143 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5152 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5153 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5154 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:39 WARN TaskSetManager: Stage 5155 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5164 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5165 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5166 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5167 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5176 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5177 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5178 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5179 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5188 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5189 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5190 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5191 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5192 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5193 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5194 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5195 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5196 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5197 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5198 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5199 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5200 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5201 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5202 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5203 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5204 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5205 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5206 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5207 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5208 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5209 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5210 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5211 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5212 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5213 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5214 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5215 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5216 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5217 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5218 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5219 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5220 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5221 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5222 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5223 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5224 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5225 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5226 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5227 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5228 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5229 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5230 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5231 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5232 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5233 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5234 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5235 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5236 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5237 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5238 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5239 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:40 WARN TaskSetManager: Stage 5240 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN Instrumentation: [27b40e88] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5241 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5242 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN Instrumentation: [006bf632] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5243 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN Instrumentation: [44cb2a5e] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:41 WARN Instrumentation: [939fd927] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5244 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5246 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5248 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5250 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5288 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:41 WARN TaskSetManager: Stage 5291 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5294 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5297 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5300 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5301 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5302 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5303 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5304 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5305 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5306 contains a task of very large size (4214 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5307 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5308 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:42 WARN TaskSetManager: Stage 5309 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:43 WARN TaskSetManager: Stage 5310 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:43 WARN TaskSetManager: Stage 5311 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:43 WARN TaskSetManager: Stage 5312 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:43 WARN TaskSetManager: Stage 5313 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.
# 24/05/16 23:15:43 WARN Instrumentation: [7a2aba29] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# Best LR model:  PipelineModel_793a89e469ee
# Best LR score:  0.5
#
#
# LogisticRegression_1dce87d45691__aggregationDepth , 2
# LogisticRegression_1dce87d45691__elasticNetParam  , 0.0
# LogisticRegression_1dce87d45691__family           , binomial
# LogisticRegression_1dce87d45691__featuresCol      , final_feature_vector
# LogisticRegression_1dce87d45691__fitIntercept     , True
# LogisticRegression_1dce87d45691__labelCol         , frontpage
# LogisticRegression_1dce87d45691__maxBlockSizeInMB , 0.0
# LogisticRegression_1dce87d45691__maxIter          , 100
# LogisticRegression_1dce87d45691__predictionCol    , prediction
# LogisticRegression_1dce87d45691__probabilityCol   , probability
# LogisticRegression_1dce87d45691__rawPredictionCol , rawPrediction
# LogisticRegression_1dce87d45691__regParam         , 0.2
# LogisticRegression_1dce87d45691__standardization  , True
# LogisticRegression_1dce87d45691__threshold        , 0.5
# LogisticRegression_1dce87d45691__tol              , 1e-06
# LogisticRegression_1dce87d45691__weightCol        , frontpage
#
#
# Test scores for LR 0.5
# 24/05/16 23:15:43 WARN TaskSetManager: Stage 5314 contains a task of very large size (3771 KiB). The maximum recommended task size is 1000 KiB.

# %%
# Training and evaluating RFC
cvModel_rfc = crossval_rfc.fit(train)


best_model_rfc = cvModel_rfc.bestModel
best_score_rfc = cvModel_rfc.avgMetrics[0]

print("Best RFC model: ", best_model_rfc)
print("Best RFC score: ", best_score_rfc)

print("\n")


best_rfc_params = best_model_rfc.stages[-1].extractParamMap()
for parameter, value in best_rfc_params.items():
    print(f"{str(parameter):50s}, {value}")

print("\n")

# Test scores
test_pred_rfc = best_model_rfc.transform(test)
print("Test scores for RFC", evaluator.evaluate(test_pred_rfc))
# Out:
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN Instrumentation: [853b5be2] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:56:59 WARN Instrumentation: [e021ba9e] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:56:59 WARN Instrumentation: [4eee773a] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:56:59 WARN Instrumentation: [52b6cd53] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:56:59 ERROR Executor: Exception in task 0.0 in stage 243.0 (TID 5196)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:56:59 WARN TaskSetManager: Lost task 0.0 in stage 243.0 (TID 5196) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:56:59 ERROR TaskSetManager: Task 0 in stage 243.0 failed 1 times; aborting job
# 24/05/16 22:56:59 ERROR Executor: Exception in task 0.0 in stage 246.0 (TID 5197)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:56:59 WARN TaskSetManager: Lost task 0.0 in stage 246.0 (TID 5197) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:56:59 ERROR TaskSetManager: Task 0 in stage 246.0 failed 1 times; aborting job
# 24/05/16 22:56:59 ERROR Executor: Exception in task 0.0 in stage 249.0 (TID 5198)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:56:59 WARN TaskSetManager: Lost task 0.0 in stage 249.0 (TID 5198) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:56:59 ERROR TaskSetManager: Task 0 in stage 249.0 failed 1 times; aborting job
# 24/05/16 22:56:59 ERROR Executor: Exception in task 0.0 in stage 252.0 (TID 5199)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:56:59 WARN TaskSetManager: Lost task 0.0 in stage 252.0 (TID 5199) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:56:59 ERROR TaskSetManager: Task 0 in stage 252.0 failed 1 times; aborting job
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:56:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 24/05/16 22:57:00 WARN Instrumentation: [ec0a389f] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:57:00 WARN Instrumentation: [5719581a] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:57:00 WARN Instrumentation: [29f9c485] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:57:00 WARN Instrumentation: [54c53d46] All labels are the same value and fitIntercept=true, so the coefficients will be zeros. Training is not needed.
# 24/05/16 22:57:00 ERROR Executor: Exception in task 0.0 in stage 281.0 (TID 5220)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:00 WARN TaskSetManager: Lost task 0.0 in stage 281.0 (TID 5220) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:57:00 ERROR TaskSetManager: Task 0 in stage 281.0 failed 1 times; aborting job
# 24/05/16 22:57:00 ERROR Executor: Exception in task 0.0 in stage 284.0 (TID 5221)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:00 WARN TaskSetManager: Lost task 0.0 in stage 284.0 (TID 5221) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:57:00 ERROR TaskSetManager: Task 0 in stage 284.0 failed 1 times; aborting job
# 24/05/16 22:57:00 ERROR Executor: Exception in task 0.0 in stage 287.0 (TID 5222)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:00 WARN TaskSetManager: Lost task 0.0 in stage 287.0 (TID 5222) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# ...
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:01 WARN TaskSetManager: Lost task 0.0 in stage 325.0 (TID 5245) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:57:01 ERROR TaskSetManager: Task 0 in stage 325.0 failed 1 times; aborting job
# 24/05/16 22:57:01 ERROR Executor: Exception in task 0.0 in stage 329.0 (TID 5246)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:01 WARN TaskSetManager: Lost task 0.0 in stage 329.0 (TID 5246) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:57:01 ERROR TaskSetManager: Task 0 in stage 329.0 failed 1 times; aborting job
# 24/05/16 22:57:01 ERROR Executor: Exception in task 0.0 in stage 332.0 (TID 5247)
# org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
# 24/05/16 22:57:01 WARN TaskSetManager: Lost task 0.0 in stage 332.0 (TID 5247) (192.168.0.173 executor driver): org.apache.spark.SparkException: [FAILED_EXECUTE_UDF] Failed to execute user defined function (`StringIndexerModel$$Lambda$5160/0x0000000801989840`: (string) => double).
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:198)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.util.collection.ExternalSorter.insertAll(ExternalSorter.scala:197)
# 	at org.apache.spark.shuffle.sort.SortShuffleWriter.write(SortShuffleWriter.scala:63)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Unseen label: 03. To handle unseen labels, set Param handleInvalid to keep.
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1(StringIndexer.scala:406)
# 	at org.apache.spark.ml.feature.StringIndexerModel.$anonfun$getIndexer$1$adapted(StringIndexer.scala:391)
# 	... 22 more
#
# 24/05/16 22:57:01 ERROR TaskSetManager: Task 0 in stage 332.0 failed 1 times; aborting job

# %%
# Training and evaluating SVC
cvModel_svc = crossval_svc.fit(train)

best_model_svc = cvModel_svc.bestModel
best_score_svc = cvModel_svc.avgMetrics[0]

print("Best RFC model: ", best_model_svc)
print("Best RFC score: ", best_score_svc)

print("\n")


best_svc_params = best_model_svc.stages[-1].extractParamMap()
for parameter, value in best_svc_params.items():
    print(f"{str(parameter):50s}, {value}")
    
print("\n")

# Test scores
test_pred_svc = best_model_svc.transform(test)
print("Test scores for SVC", evaluator.evaluate(test_pred_svc))

# %%
# save best model based on test scores: One from [best_model_lr, best_model_rfc, best_model_svc]
mPath =  file_path+"models/best_model"
best_model_lr.write().overwrite().save(mPath)
